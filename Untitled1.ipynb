# %%
import pandas as pd
weather = pd.read_csv('3480361.csv', index_col='DATE')

# %%
weather.head()
# Out:
#                 STATION          NAME  PRCP  SNWD  TAVG  TMAX  TMIN
# DATE
# 1960-02-01  TU000017062  ISTANBUL, TU   NaN   NaN   NaN  43.0  29.0
# 1960-02-02  TU000017062  ISTANBUL, TU  0.00   NaN   NaN  32.0  25.0
# 1960-02-03  TU000017062  ISTANBUL, TU  0.16   NaN   NaN  32.0  24.0
# 1960-02-04  TU000017062  ISTANBUL, TU   NaN   NaN   NaN  30.0  20.0
# 1960-02-05  TU000017062  ISTANBUL, TU  0.08   NaN   NaN  30.0  18.0

# %%
weather.apply(pd.isnull).sum()/weather.shape[0]
# Out:
# STATION    0.000000
# NAME       0.000000
# PRCP       0.596237
# SNWD       0.993559
# TAVG       0.821379
# TMAX       0.064363
# TMIN       0.051122
# dtype: float64

# %%
core_weather = weather[["PRCP","TMAX","TMIN"]].copy()

# %%
core_weather.columns = ["precip","temp_max","temp_min"]

# %%
core_weather.head()
# Out:
#             precip  temp_max  temp_min
# DATE
# 1960-02-01     NaN      43.0      29.0
# 1960-02-02    0.00      32.0      25.0
# 1960-02-03    0.16      32.0      24.0
# 1960-02-04     NaN      30.0      20.0
# 1960-02-05    0.08      30.0      18.0

# %%
core_weather.apply(pd.isnull).sum()/core_weather.shape[0]
# Out:
# precip      0.596237
# temp_max    0.064363
# temp_min    0.051122
# dtype: float64

# %%
core_weather["precip"].value_counts()
# Out:
# 0.00    2589
# 0.04    1079
# 0.08     594
# 0.12     409
# 0.16     325
#         ...
# 2.24       1
# 1.70       1
# 1.55       1
# 2.51       1
# 0.86       1
# Name: precip, Length: 154, dtype: int64

# %%
core_weather[pd.isnull(core_weather["precip"])]
# Out:
#             precip  temp_max  temp_min
# DATE
# 1960-02-01     NaN      43.0      29.0
# 1960-02-04     NaN      30.0      20.0
# 1960-02-06     NaN      36.0      19.0
# 1960-02-08     NaN      39.0      34.0
# 1960-02-09     NaN      39.0      29.0
# ...            ...       ...       ...
# 2023-08-26     NaN      93.0      73.0
# 2023-08-28     NaN      89.0      70.0
# 2023-08-29     NaN      94.0      72.0
# 2023-08-30     NaN      92.0      72.0
# 2023-08-31     NaN      92.0      74.0
#
# [11663 rows x 3 columns]

# %%
core_weather.loc["1960-02-01":"1960-03-01", :]
# Out:
#             precip  temp_max  temp_min
# DATE
# 1960-02-01     NaN      43.0      29.0
# 1960-02-02    0.00      32.0      25.0
# 1960-02-03    0.16      32.0      24.0
# 1960-02-04     NaN      30.0      20.0
# 1960-02-05    0.08      30.0      18.0
# 1960-02-06     NaN      36.0      19.0
# 1960-02-07    0.00      39.0      30.0
# 1960-02-08     NaN      39.0      34.0
# 1960-02-09     NaN      39.0      29.0
# 1960-02-10     NaN      44.0      25.0
# 1960-02-11    0.00      44.0      40.0
# 1960-02-12    0.12      53.0      34.0
# 1960-02-13     NaN      57.0      45.0
# 1960-02-14     NaN      59.0      46.0
# 1960-02-15     NaN      61.0      50.0
# 1960-02-16    0.00      57.0      47.0
# 1960-02-17    0.16      54.0      43.0
# 1960-02-18     NaN      57.0      46.0
# 1960-02-19     NaN      67.0      53.0
# 1960-02-20     NaN      64.0      44.0
# 1960-02-21    0.20      49.0      42.0
# 1960-02-22    0.00      49.0      42.0
# 1960-02-23    0.12      56.0      40.0
# ...

# %%
core_weather["precip"] = core_weather["precip"].fillna(method="ffill")

# %%
core_weather["precip"].head()
# Out:
# DATE
# 1960-02-01     NaN
# 1960-02-02    0.00
# 1960-02-03    0.16
# 1960-02-04    0.16
# 1960-02-05    0.08
# Name: precip, dtype: float64

# %%
core_weather["precip"] = core_weather["precip"].fillna(method="bfill")

# %%
core_weather["precip"].head()
# Out:
# DATE
# 1960-02-01    0.00
# 1960-02-02    0.00
# 1960-02-03    0.16
# 1960-02-04    0.16
# 1960-02-05    0.08
# Name: precip, dtype: float64

# %%
core_weather[pd.isnull(core_weather["temp_max"])]
# Out:
#             precip  temp_max  temp_min
# DATE
# 2007-05-03    0.02       NaN      49.0
# 2007-05-09    0.00       NaN      57.0
# 2014-02-25    0.49       NaN       NaN
# 2014-03-16    0.02       NaN       NaN
# 2014-03-19    0.00       NaN      46.0
# ...            ...       ...       ...
# 2023-05-16    0.00       NaN      59.0
# 2023-07-01    0.00       NaN      63.0
# 2023-07-20    0.00       NaN      71.0
# 2023-07-24    0.00       NaN       NaN
# 2023-07-27    0.00       NaN       NaN
#
# [1259 rows x 3 columns]

# %%
core_weather = core_weather.fillna(method="ffill")

# %%
core_weather = core_weather.fillna(method="bfill")

# %%
core_weather.apply(pd.isnull).sum()/core_weather.shape[0]
# Out:
# precip      0.0
# temp_max    0.0
# temp_min    0.0
# dtype: float64

# %%
core_weather.dtypes
# Out:
# precip      float64
# temp_max    float64
# temp_min    float64
# dtype: object

# %%
core_weather.index
# Out:
# Index(['1960-02-01', '1960-02-02', '1960-02-03', '1960-02-04', '1960-02-05',
#        '1960-02-06', '1960-02-07', '1960-02-08', '1960-02-09', '1960-02-10',
#        ...
#        '2023-08-22', '2023-08-23', '2023-08-24', '2023-08-25', '2023-08-26',
#        '2023-08-27', '2023-08-28', '2023-08-29', '2023-08-30', '2023-08-31'],
#       dtype='object', name='DATE', length=19561)

# %%
core_weather.index = pd.to_datetime(core_weather.index)

# %%
core_weather.index
# Out:
# DatetimeIndex(['1960-02-01', '1960-02-02', '1960-02-03', '1960-02-04',
#                '1960-02-05', '1960-02-06', '1960-02-07', '1960-02-08',
#                '1960-02-09', '1960-02-10',
#                ...
#                '2023-08-22', '2023-08-23', '2023-08-24', '2023-08-25',
#                '2023-08-26', '2023-08-27', '2023-08-28', '2023-08-29',
#                '2023-08-30', '2023-08-31'],
#               dtype='datetime64[ns]', name='DATE', length=19561, freq=None)

# %%
core_weather[["temp_max","temp_min"]].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
core_weather.index.year.value_counts().sort_index()
# Out:
# 1960    335
# 1961    365
# 1962    365
# 1963    365
# 1964    366
# 1965    365
# 1966    365
# 1967    365
# 1968    366
# 1969    365
# 1970    365
# 1971    365
# 1972    366
# 1973    365
# 1974    365
# 1975    365
# 1976    366
# 1977    365
# 1978    365
# 1979    365
# 1980    366
# 1981    365
# 1982    365
# 1983    365
# 1984    366
# 1985    365
# 1986    365
# 1987    365
# 1988    366
# 1989    365
# 1990    365
# 1991    365
# 1992    366
# 1993    365
# 1994    365
# 1995    365
# 1996    366
# 1997    365
# 1998    365
# 1999    365
# 2000    366
# 2001    365
# 2002    365
# 2003    365
# 2004     31
# 2007     18
# 2014    315
# 2015    363
# 2016    364
# 2017    365
# 2018    364
# 2019    365
# 2020    366
# 2021    362
# 2022    365
# 2023    243
# Name: DATE, dtype: int64

# %%
core_weather["precip"].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
core_weather.groupby(core_weather.index.year).sum()["precip"].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
core_weather["target"] = core_weather.shift(-1)["temp_max"]

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 1960-02-01    0.00      43.0      29.0    32.0
# 1960-02-02    0.00      32.0      25.0    32.0
# 1960-02-03    0.16      32.0      24.0    30.0
# 1960-02-04    0.16      30.0      20.0    30.0
# 1960-02-05    0.08      30.0      18.0    36.0
# ...            ...       ...       ...     ...
# 2023-08-27    0.00      88.0      73.0    89.0
# 2023-08-28    0.00      89.0      70.0    94.0
# 2023-08-29    0.00      94.0      72.0    92.0
# 2023-08-30    0.00      92.0      72.0    92.0
# 2023-08-31    0.00      92.0      74.0     NaN
#
# [19561 rows x 4 columns]

# %%
core_weather = core_weather.iloc[:-1,:].copy()

# %%
from sklearn.linear_model import Ridge

reg=Ridge(alpha=0.1)

# %%
predictors = ["precip", "temp_max","temp_min"]

# %%
train = core_weather.loc[:"2021-12-31"]

# %%
test = core_weather.loc["2022-01-01":]

# %%
reg.fit(train[predictors], train["target"])
# Out:
# Ridge(alpha=0.1)

# %%
train
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 1960-02-01    0.00      43.0      29.0    32.0
# 1960-02-02    0.00      32.0      25.0    32.0
# 1960-02-03    0.16      32.0      24.0    30.0
# 1960-02-04    0.16      30.0      20.0    30.0
# 1960-02-05    0.08      30.0      18.0    36.0
# ...            ...       ...       ...     ...
# 2021-12-27    0.00      63.0      50.0    63.0
# 2021-12-28    0.00      63.0      53.0    63.0
# 2021-12-29    0.00      63.0      50.0    61.0
# 2021-12-30    0.20      61.0      50.0    50.0
# 2021-12-31    0.00      50.0      50.0    51.0
#
# [18953 rows x 4 columns]

# %%
test
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 2022-01-01    0.00      51.0      44.0    56.0
# 2022-01-02    0.05      56.0      44.0    58.0
# 2022-01-03    0.12      58.0      42.0    58.0
# 2022-01-04    0.00      58.0      42.0    62.0
# 2022-01-05    0.00      62.0      45.0    64.0
# ...            ...       ...       ...     ...
# 2023-08-26    0.00      93.0      73.0    88.0
# 2023-08-27    0.00      88.0      73.0    89.0
# 2023-08-28    0.00      89.0      70.0    94.0
# 2023-08-29    0.00      94.0      72.0    92.0
# 2023-08-30    0.00      92.0      72.0    92.0
#
# [607 rows x 4 columns]

# %%
reg.fit(train[predictors], train["target"])
# Out:
# Ridge(alpha=0.1)

# %%
predictions = reg.predict(test[predictors])

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(test["target"], predictions)
# Out:
# 3.5397586053202743

# %%
combined = pd.concat([test["target"], pd.Series(predictions, index=test.index)], axis=1)
combined.columns = ["actual", "predictions"]

# %%
combined
# Out:
#             actual  predictions
# DATE
# 2022-01-01    56.0    52.072974
# 2022-01-02    58.0    56.474349
# 2022-01-03    58.0    58.058446
# 2022-01-04    62.0    58.062993
# 2022-01-05    64.0    61.847447
# ...            ...          ...
# 2023-08-26    88.0    91.591540
# 2023-08-27    89.0    87.188270
# 2023-08-28    94.0    87.807086
# 2023-08-29    92.0    92.384915
# 2023-08-30    92.0    90.623607
#
# [607 rows x 2 columns]

# %%
combined.plot()
# Out:
# <Axes: xlabel='DATE'>
